# %%
# Workstation Pipeline Test
print("WSL2 - Online")
print("Python - Online")
print("Jupyter - Online")
print("VS Code - Online")
# Out:
# WSL2 - Online
# Python - Online
# Jupyter - Online
# VS Code - Online
